# %% [markdown]
# # Similarity Modulation

# %% [markdown]
# Here we are going to implement another similarity other that the BM25 which is the default in Elastic. We want you to implement a tf-idf similarity and test it with same queries in phase2 so that you can get a sense of how well your Elastic tf-idf works. Follow the instructions and fill where ever it says # TODO.  <br>
# You can contact me in case of any problems via Telegram: @mahvash_sp

# %%
from elasticsearch import Elasticsearch, helpers
import json
import warnings

# %%
# import data in json format
import os

os.chdir('../../')
file_name = os.path.join(os.getcwd(), 'Phase_1', 'assets', 'IR_data_news_12k.json')

with open(file_name) as f:
    data = json.load(f)

# %%
# Filter warnings
warnings.filterwarnings('ignore')

# %%
# data keys
data['0'].keys()
# Out:
# dict_keys(['title', 'content', 'tags', 'date', 'url', 'category'])

# %%
from hazm import *

normalizer = Normalizer()

# coding: utf8
from os import path
import codecs
from hazm.Normalizer import Normalizer
# from Phase_1.src.utils import data_path
default_stop_words = path.join(os.getcwd(), 'Phase_1', 'src', 'data', 'stopwords.dat')


class StopWord:
    """ Class for remove stop words

         >>> StopWord().clean(["در","تهران","کی","بودی؟"])
         ['بودی؟', 'تهران', 'کی']
         >>> StopWord(normal=True).clean(["در","تهران","کی","بودی؟"])
         ['بودی؟', 'تهران']

         """

    def __init__(self, file_path=default_stop_words, normal=False):
        self.file_path = file_path
        self.normal = normal
        self.normalizer = Normalizer().normalize
        self.stop_words = self.init(file_path, normal)

    def init(self, file_path, normal):
        if not normal:
            return set(
                line.strip("\r\n") for line in codecs.open(file_path, "r", encoding="utf-8").readlines())
        else:
            return set(
                self.normalizer(line.strip("\r\n")) for line in
                codecs.open(file_path, "r", encoding="utf-8").readlines())

    def set_normalizer(self, func):
        self.normalizer = func
        self.stop_words = self.init(self.file_path, self.normal)

    def __getitem__(self, item):
        return item in self.stop_words

    def __str__(self):
        return str(self.stop_words)

    def clean(self, iterable_of_strings, return_generator=False):
        if return_generator:
            return filter(lambda item: not self[item], iterable_of_strings)
        else:
            return list(filter(lambda item: not self[item], iterable_of_strings))

def preprocess_content(content):
    str_empty = ' '
    stemmer = Stemmer()
    content = normalizer.normalize(content)
    content = word_tokenize(content)
    content = StopWord(normal=False).clean(content)
    content = [stemmer.stem(word) for word in content]
    content = str_empty.join(content)
    return content

for i in range(len(data)):
    data[str(i)]['content'] = preprocess_content(data[str(i)]['content'])

# %% [markdown]
# After starting your Elasticsearch on your pc (localhost:9200 is the default) we have to connect to it via the following piece of code

# %%
# Here we try to connect to Elastic
es = Elasticsearch("http://localhost:55003")

# %% [markdown]
# ## Create tf-idf Index

# %% [markdown]
# ### Create Index

# %%
# Name of index 
sm_index_name = 'tfidf_index'

# %%
# Delete index if one does exist
if es.indices.exists(index=sm_index_name):
    es.indices.delete(index=sm_index_name)

# Create index    
es.indices.create(index=sm_index_name)
# Out:
# ObjectApiResponse({'acknowledged': True, 'shards_acknowledged': True, 'index': 'tfidf_index'})

# %% [markdown]
# ### Add documents

# %% [markdown]
# In here we used the bulk doc formatter which was introduced in the first subsection of phase 3. <br>
# You can find out more in [Here](https://stackoverflow.com/questions/61580963/insert-multiple-documents-in-elasticsearch-bulk-doc-formatter).

# %%
from elasticsearch.helpers import bulk

def bulk_sync():
    actions = [
        {
            '_index': sm_index_name,
            '_id':doc_id,
            '_source': doc
        } for doc_id,doc in data.items()
    ]
    bulk(es, actions)

# %%
# run the function to add documents
bulk_sync()

# %%
# Check index
es.count(index = sm_index_name)
# Out:
# ObjectApiResponse({'count': 10500, '_shards': {'total': 1, 'successful': 1, 'skipped': 0, 'failed': 0}})

# %% [markdown]
# ### Configuring a similarity

# %% [markdown]
# In order to configure a new similarity function you have to change the similarity from the settings api of the index. This can be done via the function 'put_settings' in python. What we do is to change the 'default' similarity function in Elastic so that it uses the replaced similarity instead. Type of this similarity is set to 'scripted' because tf-idf is not among the pre-defined similarity functions in Elastic anymore. As this similarity is a scripted type the source code of it must be written **by you** and passed to it.<br>
# > In order for the changes to be applied, first we close the index and change the settings and then reopen it<br>
#
# Write the tf-idf code in a string and pass it as a value to the "source" key. <br>
# You can find the variables needed in your code in [Here](https://www.elastic.co/guide/en/elasticsearch/painless/current/painless-similarity-context.html).

# %%
source_code = "double tf = 1 + Math.log(doc.freq); double idf = Math.log((field.docCount)/(term.docFreq)); return tf * idf;"

# %%
# closing the index
es.indices.close(index=sm_index_name)

# applying the settings
es.indices.put_settings(index=sm_index_name, 
                            settings={
                                "similarity": {
                                      "default": {
                                        "type": "scripted",
                                        "script": {
                                          "source": source_code
                                        }
                                      }
                                }
                            }
                       )

# reopening the index
es.indices.open(index=sm_index_name)
# Out:
# ObjectApiResponse({'acknowledged': True, 'shards_acknowledged': True})

# %% [markdown]
# ### Query

# %% [markdown]
# In this section you have to test your index with same queries you tested phase2. The goal here is to observe how different or simillar your tf-idf Elastic implementation works.

# %%
# A function that creates appropriate body for our match content type query
def get_query(text):
    body ={
    "query":{  
        "match" : {
            "content" : text
            }
        }
    }
    
    return body

# %%
queries = [
    #TODO : add your queries in string format to this list
    "تیم استقلال",
    "مجلس",
    "یوفا",
    "نرخ استخاره",
    "تیبو کورتوا",
    "تحریم جهانی علیه کشور جهان سومی ایران در جمعه"
]

# %%
all_res_tfidf = []


for q in queries:
    res_tfidf = es.search(index=sm_index_name, body=get_query(q), explain=True)
    all_res_tfidf.append(dict(res_tfidf))

# %%
for res, q in zip(all_res_tfidf, queries):
    print(q)
    for doc in res['hits']['hits']:
        print(doc['_source']['url'])
    print("----------------------------")
# Out:
# تیم استقلال
# https://www.farsnews.ir/news/14001206000566/گفت‌و‌گوی-ویژه-با-الهامی-جعبه-سیاه-استقلالِ-حجازی-و-آقا-فیروز-از
# https://www.farsnews.ir/news/14001127000238/گفت‌و‌گوی-ویژه-با-زلزله-استقلال-به-خاکسپاری-برادرم-نرسیدم-کاپیتان
# https://www.farsnews.ir/news/14001024000498/6-نکته-از-لیگ-برتر-در-نیم-فصل-اول|-پرسپولیس-و-5-تیم-رکورددار-حاشیه-
# https://www.farsnews.ir/news/14000930000263/گفت‌وگوی-ویژه-با-مورچه-اتمی-استقلال-از-توصیه‌های-کی-روش-و-قلعه‌نویی
# https://www.farsnews.ir/news/14001210000357/اکبرپور-می-خواهند-استقلال-قهرمان-نشود-امیدوارم-رقابت-با-پرسپولیس
# https://www.farsnews.ir/news/14001015000879/هفته-چهاردهم-لیگ-برتر|کورس-سرخابی‌ها-و-سپاهان-برای-قهرمانی-نیم-فصل
# https://www.farsnews.ir/news/14001207000966/هفته-بیستم-لیگ-برتر|-استقلال-20-می-شود-پرسپولیس-مقابل-دومین-تیم
# https://www.farsnews.ir/news/14001115000506/معوقه-از-هفته-شانزدهم-لیگ-برتر|-صدرنشینی-مقتدرانه-استقلال-با-شکست
# https://www.farsnews.ir/news/14001207001061/آجورلو-از-چه-می-ترسید-که-پشت-درهای-بسته-تصمیم-می-گیرید-از-مجیدی-کسب-5
# https://www.farsnews.ir/news/14001016000365/عالمی-ژستد-و-یامگا-تفاوت‌های-زیادی-با-هم-دارند-استقلال-مقابل-مس-دچار
# ----------------------------
# مجلس
# https://www.farsnews.ir/news/14001108000520/مجلس-یازدهم-در-دست-یک-جناح-نیست-دولت-سرعت-تغییرات-را-در-بدنه-اجرایی
# https://www.farsnews.ir/news/14000927000679/جزئیات-نامه-لاریجانی-به-شورای-نگهبان-درباره-رد-صلاحیتش
# https://www.farsnews.ir/news/14001206000606/محصولیِ-۱۲-میلیاردی-را-محکوم-می‌کردند-اما-با-وزرای-۱۰۰۰-میلیاردی
# https://www.farsnews.ir/news/14001003000368/عضو-هیات-رئیسه-مجلس-25-هزار-نیروی-مازاد-با-توصیه-در-خودروسازی‌ها-جمع
# https://www.farsnews.ir/news/14001124000405/عضو-هیات‌رئیسه-مجلس-دستان-بسته-هیات-نظارت-بر-نمایندگان-را-باید-باز
# https://www.farsnews.ir/news/14000811000376/در-نشست-علنی-امروز-مجلس-چه-گذشت-ذره‌بین-مجلس-بر-متخلفان-ارز-دولتی-و
# https://www.farsnews.ir/news/14000915000506/0-هزار-کلاس-بدون-معلم-نیاز-200-هزار-میلیاردی-برای-سنددار-کردن-اموال
# https://www.farsnews.ir/news/14000910000932/حمایت-بی-چون-و-چرا-از-خودروسازان-اشتباه-محض-است-دغدغه‌ای-بجز
# https://www.farsnews.ir/news/14000907000156/گزارش-فارس-از-بررسی-صلاحیت-وزیر-جدید-آموزش-و-پرورش-نوری-و-موافقان-و
# https://www.farsnews.ir/news/14001019000672/گفت‌وگوی-مشروح-با-وکیلی-|-اصلاحات-با-بحران-منشور-حکمرانی-رو‌به‌روست-
# ----------------------------
# یوفا
# https://www.farsnews.ir/news/14001211000665/هیولای-سرمایه‌داری-به-جان-چلسی-افتاد-مالک-روس-قربانی-شعار-تو-خالی
# https://www.farsnews.ir/news/14001210000293/دردسر-جدید-تیم‌های-بزرگ-ایتالیا-نقض-قانون-فیرپلی-مالی-به-خاطر-کرونا
# https://www.farsnews.ir/news/14001212000620/تصمیم-جدی-0-باشگاه-برای-آغاز-دوباره-سوپرلیگ--تهدید-یوفا-به-حذف-از-لیگ
# https://www.farsnews.ir/news/14001111000089/درخواست-یوفا-از-آنچلوتی-با-2-قهرمانی-آزمون-مربیگری-بده
# https://www.farsnews.ir/news/14001217000240/شکایت-روسیه-از-یوفا-و-فیفا-به-CAS
# https://www.farsnews.ir/news/14001206000364/تکرار-سناریوی-تغییر-میزبان-فینال-لیگ-قهرمانان-اروپا-پاریس-جانشین-سن
# https://www.farsnews.ir/news/14001030000493/هشدار-یوفا-به-رئال-و-چلسی-در-خصوص-واکسیناسیون
# https://www.farsnews.ir/news/14001011000601/یوفا-چرا-با-برگزاری-جام-جهانی-در-هر-2-سال-مخالف-است
# https://www.farsnews.ir/news/14000929000493/نتیجه-بازی-تاتنهام-3-بر-صفر-شد-حذف-تیمِ-کونته-از-رقابت-اروپایی
# https://www.farsnews.ir/news/14001221000415/عصبانیت-الخلیفی-بعد-از-باخت-به-رئال-کار-دستش-داد
# ----------------------------
# نرخ استخاره
# https://www.farsnews.ir/news/14001206000566/گفت‌و‌گوی-ویژه-با-الهامی-جعبه-سیاه-استقلالِ-حجازی-و-آقا-فیروز-از
# https://www.farsnews.ir/news/14001117000485/ارز-4200-تومانی-برای-برخی-واردکنندگان-کالاهای-اساسی-رانت-ایجاد-کرد
# https://www.farsnews.ir/news/14001221000788/سیاست‌گذاری‌های-ارزی-دهه-90-همواره-در-جهت-تضعیف-ارزش-پول-ملی-حرکت
# https://www.farsnews.ir/news/14000907000343/دولت-برنامه-دوساله-تحول-اقتصادی-خود-را-منتشر-کند-شرایط-بهتری-در-سال
# https://www.farsnews.ir/news/14001106000448/ابلاغیه-معاون-اول-رئیس‌جمهور-برای-حمایت-از-بازار-سرمایه
# https://www.farsnews.ir/news/14000726000910/گزارش-مجلس-از-عملکرد-بخش-خارجی-اقتصاد-در-سال-399-کاهش-3-درصدی-تجارت
# https://www.farsnews.ir/news/14001221000146/نامه-بازرس-ویژه-رئیس‌جمهور-به-رئیس‌کل-بانک-مرکزی-اخذ-وثایق-نقدی-در
# https://www.farsnews.ir/news/14001214000626/فراز-و-فرودهای-دلار-4200-تومانی|-ارز-ترجیحی-حذف-نمی‌شود-تغییر-شکل
# https://www.farsnews.ir/news/14000910000355/برای-مهار-نرخ-ارز-راهی-جز-تأثیر-گذاشتن-بر-عرضه-و-تقاضا-وجود-ندارد
# https://www.farsnews.ir/news/14001004000317/ارز-ترجیحی-استخوانی-در-گلو
# ----------------------------
# تیبو کورتوا
# https://www.farsnews.ir/news/14001127000168/واکنش-کورتوا-به-گرفتن-پنالتی-مسی-فیلم
# https://www.farsnews.ir/news/14001220000502/بیرانوند-در-جمع-بهترین-پنالتی‌گیرهای-جام-جهانی-عکس
# https://www.farsnews.ir/news/14001218000985/ترکیب-منتخب-رئال-و-پاریس-به-بهانه-دیدار-حساس-امشب-در-لیگ-قهرمانان-عکس
# https://www.farsnews.ir/news/14001213000563/ستاره-بلژیکی-بهترین-بازیکن-ماه-رئال-مادرید
# https://www.farsnews.ir/news/14001115000064/جام-حذفی-اسپانیا|-رئال-مادرید-حذف-شد
# https://www.farsnews.ir/news/14001008000860/رئال-مادرید-4-کرونایی-جدید-داد
# https://www.farsnews.ir/news/14001127000319/مطبوعات-اروپا-در-تمجید-امباپه-چقدر-تو-خوبی-پسر-تصاویر
# https://www.farsnews.ir/news/14001127001476/رکوردداران-از-دست-دادن-پنالتی-در-لیگ-قهرمانان-اروپا-اختلاف-مسی-و
# https://www.farsnews.ir/news/14001127000157/واکنش-آنچلوتی-به-شکست-مقابل-پاری-سن-ژرمن
# https://www.farsnews.ir/news/14001026001169/سوپرکاپ-اسپانیا|رئال-با-غلبه-بر-بیلبائو-قهرمان-شد-تصاویر
# ----------------------------
# تحریم جهانی علیه کشور جهان سومی ایران در جمعه
# https://www.farsnews.ir/news/14001121000352/دعوت-احزاب-و-شخصیت‌های-سیاسی-از-مردم-برای-حضور-در-راهپیمایی-22بهمن
# https://www.farsnews.ir/news/14000813000113/گزارش-فارس-از-اجتماع-میدانی-یوم-الله-3-آبان-در-تهران-تاکید-بر-ضرورت
# https://www.farsnews.ir/news/14001030000671/رییس-جمهور-در-مسکو-از-تاکید-پوتین-بر-توسعه-روابط-با-ایران-تا-تشویق
# https://www.farsnews.ir/news/14000926000407/آمریکا-با-راستی‌آزمایی-لغو-تحریم‌ها-مشکل-دارد-اطلاع-روحانی-از-ماجرای
# https://www.farsnews.ir/news/14000803000676/اهرم‌سازی-از-افغانستان-در-برجام-نقطه-عزیمت-آمریکا-در-مذاکرات-جامع-با
# https://www.farsnews.ir/news/14001010000511/دومین-روز-سفر-رئیس‌جمهور-به-قم--از-حضور-در-نماز-جمعه-تا-دیدار-با
# https://www.farsnews.ir/news/14000908000309/نایب-رئیس-مجلس-رژیم-صهیونیستی-با-حمایت-آمریکا-دست-به-هر-جنایتی-می‌زند
# https://www.farsnews.ir/news/14000816000568/ماجرای-دستگیری-دو-دانشمند-ایرانی-در-آمریکا-سلیمانی-مرا-در-بند
# https://www.farsnews.ir/news/14001203000404/رئیس‌جمهور-جامعه-جهانی-مانع-تحریم-آمریکا-علیه-صادرکنندگان-گاز-شود
# https://www.farsnews.ir/news/14000902000005/سخنان-نخبگان-در-دیدار-با-رهبر-انقلاب-سال-۶۸-حضرت-آیت-الله-خامنه‌ای-به
# ----------------------------
